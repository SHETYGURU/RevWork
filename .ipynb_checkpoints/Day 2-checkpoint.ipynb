# %%
st={'apple','orange','mango','banana','apple','mango'}

# %%
st
# Out:
# {'apple', 'banana', 'mango', 'orange'}

# %%
type(st)
# Out:
# set

# %%
#Set OPerations

# %%
st.add('pinaple')

# %%
st
# Out:
# {'apple', 'banana', 'mango', 'orange', 'pinaple'}

# %%
st2={'apple','mango','chikku','orange','fig'}

# %%
st.union(st2)
# Out:
# {'apple', 'banana', 'chikku', 'fig', 'mango', 'orange', 'pinaple'}

# %%
st|st2
# Out:
# {'apple', 'banana', 'chikku', 'fig', 'mango', 'orange', 'pinaple'}

# %%
st.intersection(st2)
# Out:
# {'apple', 'mango', 'orange'}

# %%
st&st2
# Out:
# {'apple', 'mango', 'orange'}

# %%
st-st2
# Out:
# {'banana', 'pinaple'}

# %%
st.difference(st2)
# Out:
# {'banana', 'pinaple'}

# %%
st2-st
# Out:
# {'chikku', 'fig'}

# %%
st.update(st2)

# %%
st
# Out:
# {'apple', 'banana', 'chikku', 'fig', 'mango', 'orange', 'pinaple'}

# %%
st-st2
# Out:
# {'banana', 'pinaple'}

# %%
st={'apple','orange','mango','banana','apple','mango'}
st2={'apple','mango','chikku','orange','fig'}

# %%
st.intersection_update(st2)

# %%
st
# Out:
# {'apple', 'mango', 'orange'}

# %%
st={'apple','orange','mango','banana','apple','mango'}
st2={'apple','mango','chikku','orange','fig'}
st.difference_update(st2)

# %%
st
# Out:
# {'banana'}

# %%
st.discard('banana')

# %%
st
# Out:
# set()

# %%
st={'apple','orange','mango','banana','apple','mango'}
st2={'apple','mango','chikku','orange','fig'}
st.isdisjoint(st2)
# Out:
# False

# %%
st.issubset(st2)
# Out:
# False

# %%
st.issuperset(st2)
# Out:
# False

# %%
st={'apple','orange','mango','banana','apple','mango'}
st2={'apple','mango','chikku','orange','fig'}

# %%
st.remove('apple')
st
# Out:
# {'banana', 'mango', 'orange'}

# %%
st.remove('apple')
st
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 st.remove('apple')
#       2 st
#
# KeyError: 'apple'

# %%
st.discard('mango')
st
# Out:
# {'banana', 'orange'}

# %%
st.discard('mango')
st
# Out:
# {'banana', 'orange'}

# %%
st={'apple','orange','mango','banana','apple','mango'}
st2={'apple','mango','chikku','orange','fig'}

# %%
st.symmetric_difference(st2)
# Out:
# {'banana', 'chikku', 'fig'}

# %%
st.symmetric_difference_update(st2)

# %%
#Dictionary

# %%
dic ={'name':'guru','age':'23','city':'bangalore'}

# %%
dic
# Out:
# {'name': 'guru', 'age': '23', 'city': 'bangalore'}

# %%
print(dic['name'])
# Out:
# guru

# %%
x=dict([(1,'one'),(2,'two')])

# %%
x
# Out:
# {1: 'one', 2: 'two'}

# %%
dic['city']='Mangalore'
dic['salary']='450000'
dic
# Out:
# {'name': 'guru', 'age': '23', 'city': 'Mangalore', 'salary': '450000'}

# %%
dic.get('name')
# Out:
# 'guru'

# %%
lst=['a','b','c','d']
mydict=dic.fromkeys(lst)
mydict
# Out:
# {'a': None, 'b': None, 'c': None, 'd': None}

# %%
lst=['a','b','c','d']
mydict=dic.fromkeys(lst,100)
mydict
# Out:
# {'a': 100, 'b': 100, 'c': 100, 'd': 100}

# %%
mydict.keys()
# Out:
# dict_keys(['a', 'b', 'c', 'd'])

# %%
mydict.values()
# Out:
# dict_values([100, 100, 100, 100])

# %%
for i in dic.keys():
    print(i ,' :', dic[i])
# Out:
# name  : guru
# age  : 23
# city  : Mangalore
# salary  : 450000

# %%
dic.items()
# Out:
# dict_items([('name', 'guru'), ('age', '23'), ('city', 'Mangalore'), ('salary', '450000')])

# %%
for k,v in dic.items():
    print(k,' :',v)
# Out:
# name  : guru
# age  : 23
# city  : Mangalore
# salary  : 450000

# %%
dic.update({'phone':1234})

# %%
dic
# Out:
# {'name': 'guru',
#  'age': '23',
#  'city': 'Mangalore',
#  'salary': '450000',
#  'phone': 1234}

# %%
dic.update({'city':'bangalore'})
dic
# Out:
# {'name': 'guru',
#  'age': '23',
#  'city': 'bangalore',
#  'salary': '450000',
#  'phone': 1234}

# %%
dic.pop('phone')
dic
# Out:
# {'name': 'guru', 'age': '23', 'city': 'bangalore', 'salary': '450000'}

# %%
dic.popitem()
# Out:
# ('salary', '450000')

# %%
dic
# Out:
# {'name': 'guru', 'age': '23', 'city': 'bangalore'}

# %%
dic.setdefault('name','guy')
# Out:
# 'guru'

# %%
dic.setdefault('gender','male')
# Out:
# 'male'

# %%
dic
# Out:
# {'name': 'guru', 'age': '23', 'city': 'bangalore', 'gender': 'male'}

# %%
#Nested Dictionary

# %%
ppl={1:{'name': 'guru', 'age': '23', 'city': 'bangalore', 'gender': 'male'},
     2:{'name': 'sony', 'age': '23', 'city': 'mangalore', 'gender': 'female'}
    }

# %%
print(ppl[1]['name'])
print(ppl[2]['name'])
# Out:
# guru
# sony

# %%
ppl[3]={'name': 'raj', 'age': '23', 'city': 'banngalore', 'gender': 'male'}

# %%
ppl
# Out:
# {1: {'name': 'guru', 'age': '23', 'city': 'bangalore', 'gender': 'male'},
#  2: {'name': 'sony', 'age': '23', 'city': 'mangalore', 'gender': 'female'},
#  3: {'name': 'raj', 'age': '23', 'city': 'banngalore', 'gender': 'male'}}

# %%
ppl[3]['age']=24
ppl[3]
# Out:
# {'name': 'raj', 'age': 24, 'city': 'banngalore', 'gender': 'male'}

# %%
del ppl[3]['gender']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 del ppl[3]['gender']
#       2 ppl[3]
#
# KeyError: 'gender'

# %%
ppl[3]
# Out:
# {'name': 'raj', 'age': 24, 'city': 'banngalore'}

# %%
del ppl[3]
ppl
# Out:
# {1: {'name': 'guru', 'age': '23', 'city': 'bangalore', 'gender': 'male'},
#  2: {'name': 'sony', 'age': '23', 'city': 'mangalore', 'gender': 'female'}}

# %%
for p_id ,p_info in ppl.items():
    print('Person_id : ',p_id)
    for k,v in p_info.items():
        print(k,': ',v)
# Out:
# Person_id :  1
# name :  guru
# age :  23
# city :  bangalore
# gender :  male
# Person_id :  2
# name :  sony
# age :  23
# city :  mangalore
# gender :  female

# %%
#Named Tuples

# %%
# NamedTuple is present inside the collections module.
# It provides a way to create simple, lightweight data structures.

from collections import namedtuple

Student = namedtuple('Student', ['name', 'age', 'DOB'])

S = Student('Nandini', '19', '2541997')

print("The Student age using index is : ", end="")
print(S[1])

print("The Student name using keyname is : ", end="")
print(S.name)
# Out:
# The Student age using index is : 19
# The Student name using keyname is : Nandini

# %%
#Array

import array as arr
a=arr.array('i',[1,2,3])
print('Array : ',a)
print('first element : ',a[0])
a.append(4)
print('After appending : ',a)
a.insert(2,10)
print('After Inserting : ',a)
print('Count : ',a.count(1))
a.remove(2)
print('After Removing : ',a)
a.reverse()
print('After reversing : ',a)
# Out:
# Array :  array('i', [1, 2, 3])
# first element :  1
# After appending :  array('i', [1, 2, 3, 4])
# After Inserting :  array('i', [1, 2, 10, 3, 4])
# Count :  1
# After Removing :  array('i', [1, 10, 3, 4])
# After reversing :  array('i', [4, 3, 10, 1])

# %%
#Operators
num1 = 10
num2 = 20
#f is used for f-strings in Python.
#It lets you put variables directly inside a string using {}.

print(f"Addition: {num1} + {num2} = {num1 + num2}")
print(f"Subtraction: {num1} - {num2} = {num1 - num2}")
print(f"Multiplication: {num1} * {num2} = {num1 * num2}")
print(f"Division: {num1} / {num2} = {num1 / num2}")
print(f"Floor Division: {num1} // {num2} = {num1 // num2}")
print(f"Modulus: {num1} % {num2} = {num1 % num2}")
print(f"Exponent: {num1} ** {num2} = {num1 ** num2}")
# Out:
# Addition: 10 + 20 = 30
# Subtraction: 10 - 20 = -10
# Multiplication: 10 * 20 = 200
# Division: 10 / 20 = 0.5
# Floor Division: 10 // 20 = 0
# Modulus: 10 % 20 = 10
# Exponent: 10 ** 20 = 100000000000000000000

# %%
x = 5

print('x : ',x)

x += 3
print(f'Addition equals {x}')

x -= 2
print(f'Subtraction equals {x}')

x *= 4
print(f'Multiplication equals {x}')

x /= 2
print(f'Division equals {x}')

x //= 2
print(f'Floor Division equals {x}')

x %= 3
print(f'Modulus equals {x}')

x **= 2
print(f'Exponent equals {x}')
# Out:
# x :  5
# Addition equals 8
# Subtraction equals 6
# Multiplication equals 24
# Division equals 12.0
# Floor Division equals 6.0
# Modulus equals 0.0
# Exponent equals 0.0

# %%
#Comparision Operator
x=5
y=3
print('x : ',x,',y : ',y)
print('x==y :',x==y)
print('x!=y :',x!=y)
print('x>y :',x>y)
print('x<y :',x<y)
print('x>=y :',x>=y)
print('x<=y :',x<=y)
print('x>3 and x<10 :',x>3 and x<10)
print('x>3 and y>10 :',x>3 and y>10)
# Out:
# x :  5 ,y :  3
# x==y : False
# x!=y : True
# x>y : True
# x<y : False
# x>=y : True
# x<=y : False
# x>3 and x<10 : True
# x>3 and y>10 : False

# %%
x=['apple','banana']
y=['apple','banana']

print('x is y : ',x is y)
print('id(x) : ',id(x))
print('id(y) : ',id(y))
# Out:
# x is y :  False
# id(x) :  2492514189888
# id(y) :  2492514191360

# %%
z=x
print('x is z : ',x is z)
print('id(x) : ',id(x))
print('id(z) : ',id(z))
print('x is not y : ',x is not  y)
# Out:
# x is z :  True
# id(x) :  2492514184064
# id(z) :  2492514184064
# x is not y :  True

# %%
#Membership Operator
x=['apple','banana']
print('banana in x :','banana' in x)
print('fig in x :','fig' in x)
print('fig not in x :','fig'not  in x)
# Out:
# banana in x : True
# fig in x : False
# fig not in x : True

# %%
#Bitwise Operators(&,|,^,<<,>>)
print('6&3 :', 6&3)
print('6|3 :', 6|3)
print('6^3 :', 6^3)
print('6<<2 :', 6<<2)
print('6>>2 :', 6>>2)
# Out:
# 6&3 : 2
# 6|3 : 7
# 6^3 : 5
# 6<<2 : 24
# 6>>2 : 1

# %%
#type Casting

#implecit
x=5
y=2.5
print(x,'+',y,': ',x+y)
# Out:
# 5 + 2.5 :  7.5

# %%
#Explicit
x=5
print(x,': ',float(x))
# Out:
# 5 :  5.0

# %%
x='100'
print('int(',x,'): ',int(x))
# Out:
# int( 100 ):  100

# %%
x=0
print('bool(',x,'): ',bool(x))
# Out:
# bool( 0 ):  False

# %%
#Collection Casting
lst =list((10,20,30,40)) #tuple to list
lst
# Out:
# [10, 20, 30, 40]

# %%
tuple(lst)    #list to tuple
# Out:
# (10, 20, 30, 40)

# %%
set(lst) #list to set
# Out:
# {10, 20, 30, 40}

# %%
x=None
# x=10
print('x : ',x)
print('type(x) : ',type(x))

if x is None:
    print('No Value')
else :
    print('Value Exist .(',x,')')
# Out:
# x :  None
# type(x) :  <class 'NoneType'>
# No Value

# %%
age = input("Enter your Age :")
print(f"you are {age} years old and  ")
if int(age)>=18:
    print('eligible to vote')
else :
    print('not eligible to vote')
# Out:
# Enter your Age : 18
# you are 18 years old and
# eligible to vote

# %%
type(age)
# Out:
# str

# %%
marks = int(input("Enter your marks : "))

if marks >= 90:
    print("Grade A+")
elif marks >= 75:
    print("Grade A")
elif marks >= 60:
    print("Grade B")
elif marks >= 40:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter your marks :  99
# Grade A+

# %%
while True:
    username =input("Enter Username : ")
    password = input("Enter Password : ")
    if username!='admin' and password!='1234':
        print("Invalid Username and Password")
    elif  username=='admin' and password!='1234':
        print("Invalid  Password")      
    elif  username!='admin' and password=='1234':
        print("Invalid  Username") 
    else:
        print("Login Successful")
        x=int(input("1.Exit   2.Logout"))
        if x==1:
            print("Exit Sucessful")
            break
        elif x==2:
            print("Logged out Sucessfully")
            
        else :
            print("Invalid Choice")
# Out:
# Enter Username :  10
# Enter Password :  1
# Invalid Username and Password
# Enter Username :  admin
# Enter Password :  1234
# Login Successful
# 1.Exit   2.Logout 2
# Logged out Sucessfully
# Enter Username :  admin
# Enter Password :  1234
# Login Successful
# 1.Exit   2.Logout 1
# Exit Sucessful

# %%
num1 = int(input("Enter first number : "))
num2 = int(input("Enter second number : "))

while True:
    print("1.Addition")
    print("2.Subtraction")
    print("3.Multiplication")
    print("4.Division")
    print("5.Exit")

    choice = int(input("Enter choice : "))

    match choice:
        case 1:
            print("\n",f"{num1}+{num2}={num1+num2}","\n")
        case 2:
            print("\n",f"{num1}-{num2}={num1-num2}","\n")
        case 3:
            print("\n",f"{num1}*{num2}={num1*num2}","\n")
        case 4:
            print("\n",f"{num1}/{num2}={num1/num2}","\n")
        case 5:
            print("\n","Program Ended","\n")
            break
        case _:
            print("\n","Invalid Choice","\n")
# Out:
# Enter first number :  20
# Enter second number :  50
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Exit
# Enter choice :  77
#  Invalid Choice
#
# 1.Addition
# 2.Subtraction
# 3.Multiplication
# 4.Division
# 5.Exit
# Enter choice :  5
#  Program Ended
